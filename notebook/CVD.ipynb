# %% [markdown]
# # Dataset Description
#
# The dataset contains the following columns along with their data types and descriptions:
#
# | Column Name            | Data Type   | Description                                                                 |
# |------------------------|-------------|-----------------------------------------------------------------------------|
# | **id**                | `int64`     | Identifier for each entry.                                                  |
# | **age**               | `int64`     | Age in days.                                                               |
# | **gender**            | `int64`     | Gender of the individual.                                                  |
# | **height**            | `int64`     | Height in centimeters.                                                     |
# | **weight**            | `float64`   | Weight in kilograms.                                                       |
# | **ap_hi**             | `int64`     | Systolic blood pressure.                                                   |
# | **ap_lo**             | `int64`     | Diastolic blood pressure.                                                  |
# | **cholesterol**       | `int64`     | Cholesterol level categories.                                              |
# | **gluc**              | `int64`     | Glucose level categories.                                                  |
# | **smoke**             | `int64`     | Smoking status (binary).                                                   |
# | **alco**              | `int64`     | Alcohol consumption status (binary).                                       |
# | **active**            | `int64`     | Physical activity status (binary).                                         |
# | **cardio**            | `int64`     | Presence of cardiovascular disease (binary).                               |
# | **age_years**         | `int64`     | Age in years (derived from age in days).                                   |
# | **bmi**               | `float64`   | Body Mass Index (calculated from height and weight).                       |
# | **bp_category**       | `object`    | Blood pressure category (e.g., normal, high, etc.).                       |
# | **bp_category_encoded** | `object`  | Encoded representation of blood pressure categories.                       |
#
# ## Notes:
# - The `cardio` column indicates the presence (`1`) or absence (`0`) of cardiovascular disease.
# - Derived columns such as `age_years` and `bmi` are calculated for ease of analysis.
# - Categorical columns like `gender`, `cholesterol`, and `gluc` represent predefined categories.
#
# This dataset can be used for a variety of analyses, including predictive modeling, statistical studies, and visualization tasks related to cardiovascular health.

# %% [markdown]
# # Load  Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
data_path = '/kaggle/input/sonyvaichina/cardio_data_processed.csv'  # Update this path for each dataset
data = pd.read_csv(data_path)

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 68200  99993  19240       2     168    76.0    120     80            1     1
# 68201  99995  22601       1     158   126.0    140     90            2     2
# 68202  99996  19066       2     183   105.0    180     90            3     1
# 68203  99998  22431       1     163    72.0    135     80            1     2
# 68204  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'age_years',
#        'bmi', 'bp_category', 'bp_category_encoded'],
#       dtype='object')

# %% [markdown]
# # 1. Basic Information

# %%
print("Dataset Overview")
print("Shape of the dataset:", data.shape)
print(" ")
print("Columns in the dataset:")
print(data.columns)
print(" ")
print("\nData types and non-null counts:")
data.info()
print(" ")
print("\nSample data:")
data.head()
# Out:
# Dataset Overview
# Shape of the dataset: (68205, 17)
#
# Columns in the dataset:
# Index(['id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'age_years',
#        'bmi', 'bp_category', 'bp_category_encoded'],
#       dtype='object')
#
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68205 entries, 0 to 68204
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   68205 non-null  int64
#  1   age                  68205 non-null  int64
#  2   gender               68205 non-null  int64
#  3   height               68205 non-null  int64
#  4   weight               68205 non-null  float64
#  5   ap_hi                68205 non-null  int64
#  6   ap_lo                68205 non-null  int64
#  7   cholesterol          68205 non-null  int64
# ...

# %% [markdown]
# # 2. Statistical Summary

# %%
print("\nStatistical Summary:")
data.describe()
# Out:
# Statistical Summary:
#                  id           age        gender        height        weight  \
# count  68205.000000  68205.000000  68205.000000  68205.000000  68205.000000
# mean   49972.410498  19462.667737      1.348625    164.372861     74.100688
# std    28852.138290   2468.381854      0.476539      8.176756     14.288862
# min        0.000000  10798.000000      1.000000     55.000000     11.000000
# 25%    24991.000000  17656.000000      1.000000    159.000000     65.000000
# 50%    50008.000000  19700.000000      1.000000    165.000000     72.000000
# 75%    74878.000000  21323.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  68205.000000  68205.000000  68205.000000  68205.000000  68205.000000
# mean     126.434924     81.263925      1.363243      1.225174      0.087662
# ...

# %% [markdown]
# # 3. Checking for Missing Values

# %%
missing_values = data.isnull().sum()
print("\nMissing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# id                     0
# age                    0
# gender                 0
# height                 0
# weight                 0
# ap_hi                  0
# ap_lo                  0
# cholesterol            0
# gluc                   0
# smoke                  0
# alco                   0
# active                 0
# cardio                 0
# age_years              0
# bmi                    0
# bp_category            0
# bp_category_encoded    0
# dtype: int64

# %% [markdown]
# # Visualization of Missing Data

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# # 4. Duplicates

# %%
duplicates = data.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicates)
# Out:
# Number of Duplicate Rows: 0

# %% [markdown]
# # 5. Distribution of Numerical Features

# %%
numerical_cols = data.select_dtypes(include=['int64', 'float64']).columns

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 68200  99993  19240       2     168    76.0    120     80            1     1
# 68201  99995  22601       1     158   126.0    140     90            2     2
# 68202  99996  19066       2     183   105.0    180     90            3     1
# 68203  99998  22431       1     163    72.0    135     80            1     2
# 68204  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
# Plot Distribution of Numerical Features in a Row (3 per Row)
num_cols = len(numerical_cols)
rows = (num_cols // 3) + int(num_cols % 3 != 0)  # Calculate rows based on 3 plots per row

fig, axes = plt.subplots(rows, 3, figsize=(18, 4 * rows))
axes = axes.flatten()  # Flatten the axes for easier indexing

for i, col in enumerate(numerical_cols):
    sns.histplot(data[col], kde=True, bins=30, ax=axes[i], color='blue')
    axes[i].set_title(f"Distribution of {col}")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")

# Hide any empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # 6. Correlation Matrix

# %%
# Filter only numeric columns
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Plot the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # 7. Boxplots to Detect Outliers

# %%
# Plot Boxplots for Numerical Features in Rows of 3
num_cols = len(numerical_cols)
rows = (num_cols // 3) + int(num_cols % 3 != 0)  # Calculate the number of rows needed

fig, axes = plt.subplots(rows, 3, figsize=(18, 5 * rows))  # Adjust figure size as needed
axes = axes.flatten()  # Flatten axes array for easier indexing

for i, col in enumerate(numerical_cols):
    sns.boxplot(data[col], ax=axes[i], color='cyan')
    axes[i].set_title(f"Boxplot of {col}")
    axes[i].set_xlabel(col)

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# # 8. Categorical Data Analysis

# %%
categorical_cols = data.select_dtypes(include=['object', 'category']).columns
print("\nCategorical Columns:", categorical_cols)

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=data, palette='Set2')
    plt.title(f"Countplot of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
# Out:
# Categorical Columns: Index(['bp_category', 'bp_category_encoded'], dtype='object')

# %% [markdown]
# # 9. Pair Plot (Selected Columns)

# %%
pair_cols = numerical_cols[:5]  # Adjust based on dataset size
sns.pairplot(data[pair_cols], diag_kind='kde', corner=True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Clean the dataset

# %%
data = data[['id', 'age', 'gender', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'age_years', 'bmi', 'bp_category', 'bp_category_encoded']]

# %%
# import pandas as pd
# import numpy as np

# # Load your dataset (already loaded as 'data' in this case)

# # Function to detect outliers using IQR
# def detect_outliers_iqr(df, column):
#     Q1 = df[column].quantile(0.25)
#     Q3 = df[column].quantile(0.75)
#     IQR = Q3 - Q1
#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR
#     return (df[column] < lower_bound) | (df[column] > upper_bound)

# # Replace null values
# for col in data.columns:
#     if data[col].isnull().sum() > 0:  # Check if there are missing values
#         if data[col].dtype in ['int64', 'float64']:  # Numeric columns
#             data[col].fillna(data[col].mean(), inplace=True)
#         else:  # Categorical columns
#             data[col].fillna(data[col].mode()[0], inplace=True)

# # Replace outliers with the mean value
# for col in data.select_dtypes(include=['int64', 'float64']).columns:
#     outliers = detect_outliers_iqr(data, col)
#     if outliers.any():
#         mean_value = data[col].mean()
#         data.loc[outliers, col] = mean_value

# %%
# data.isnull().sum()

# %%
# # Plot Boxplots for Numerical Features in Rows of 3
# num_cols = len(numerical_cols)
# rows = (num_cols // 3) + int(num_cols % 3 != 0)  # Calculate the number of rows needed

# fig, axes = plt.subplots(rows, 3, figsize=(18, 5 * rows))  # Adjust figure size as needed
# axes = axes.flatten()  # Flatten axes array for easier indexing

# for i, col in enumerate(numerical_cols):
#     sns.boxplot(data[col], ax=axes[i], color='cyan')
#     axes[i].set_title(f"Boxplot of {col}")
#     axes[i].set_xlabel(col)

# # Hide any unused subplots
# for j in range(i + 1, len(axes)):
#     fig.delaxes(axes[j])

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Age

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Assuming 'data' is already loaded
age_cardio = data[['age', 'cardio']]

# Convert 'age' from days to years if not done already
if 'age_years' not in data.columns:
    data['age_years'] = (data['age'] / 365).astype(int)
age_cardio['age_years'] = data['age_years']
# Out:
# <ipython-input-107-db757ee93719>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_cardio['age_years'] = data['age_years']

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=age_cardio, x='age_years', hue='cardio', kde=True, bins=30, palette="Set2")
plt.title('Age Distribution by Cardiovascular Disease')
plt.xlabel('Age (years)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=age_cardio, x='cardio', y='age_years', palette="Set3")
plt.title('Age vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('Age (years)')
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Disease'])
plt.show()

# %%
correlation = age_cardio.corr()
print("Correlation between Age and Cardiovascular Disease:")
print(correlation)
# Out:
# Correlation between Age and Cardiovascular Disease:
#                 age    cardio  age_years
# age        1.000000  0.239032   0.999092
# cardio     0.239032  1.000000   0.238875
# age_years  0.999092  0.238875   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlation matrix
correlation = age_cardio.corr()

# Plot the correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Heatmap: Age vs Cardiovascular Disease")
plt.show()

# %% [markdown]
# ## Gender

# %%
Gender = data[['gender','cardio']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='gender', hue='cardio', palette="Set2")
plt.title('Gender vs Cardiovascular Disease')
plt.xlabel('Gender (1 = Female, 2 = Male)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Calculate proportions
gender_cardio = data.groupby(['gender', 'cardio']).size().reset_index(name='count')
gender_cardio['proportion'] = gender_cardio['count'] / gender_cardio.groupby('gender')['count'].transform('sum')

plt.figure(figsize=(8, 6))
sns.barplot(data=gender_cardio, x='gender', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Gender')
plt.xlabel('Gender (1 = Female, 2 = Male)')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Pie chart data preparation
gender_cardio_pie = data.groupby('gender')['cardio'].value_counts().unstack()

# Pie chart for Female (1)
plt.figure(figsize=(6, 6))
gender_cardio_pie.loc[1].plot.pie(autopct='%1.1f%%', labels=['No Disease', 'Disease'], colors=['lightblue', 'salmon'])
plt.title('Cardiovascular Disease Distribution for Females')
plt.ylabel('')
plt.show()

# Pie chart for Male (2)
plt.figure(figsize=(6, 6))
gender_cardio_pie.loc[2].plot.pie(autopct='%1.1f%%', labels=['No Disease', 'Disease'], colors=['lightgreen', 'coral'])
plt.title('Cardiovascular Disease Distribution for Males')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='gender', y='cardio', palette="Set3")
plt.title('Gender vs Cardiovascular Disease')
plt.xlabel('Gender (1 = Female, 2 = Male)')
plt.ylabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.show()

# %%
# Compute correlation matrix
gender_cardio_corr = data[['gender', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(gender_cardio_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Gender vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## ap_hi

# %%
ap_hi = data[['ap_hi','cardio']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='ap_hi', y='cardio', alpha=0.5)
plt.title('Scatter Plot: Systolic Blood Pressure (ap_hi) vs Cardiovascular Disease')
plt.xlabel('Systolic Blood Pressure (ap_hi)')
plt.ylabel('Cardiovascular Disease (cardio)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='cardio', y='ap_hi', palette="Set3")
plt.title('Boxplot: Systolic Blood Pressure (ap_hi) vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('Systolic Blood Pressure (ap_hi)')
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Disease'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=data, x='cardio', y='ap_hi', palette="Set2", split=True)
plt.title('Violin Plot: Systolic Blood Pressure (ap_hi) vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('Systolic Blood Pressure (ap_hi)')
plt.show()

# %%
# Compute correlation matrix
ap_hi_corr = data[['ap_hi', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(ap_hi_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: ap_hi vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## ap_lo

# %%
ap_lo = data[['ap_lo','cardio']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='ap_lo', y='cardio', alpha=0.5)
plt.title('Scatter Plot: Diastolic Blood Pressure (ap_lo) vs Cardiovascular Disease')
plt.xlabel('Diastolic Blood Pressure (ap_lo)')
plt.ylabel('Cardiovascular Disease (cardio)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='cardio', y='ap_lo', palette="Set3")
plt.title('Boxplot: Diastolic Blood Pressure (ap_lo) vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('Diastolic Blood Pressure (ap_lo)')
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Disease'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=data, x='cardio', y='ap_lo', palette="Set2", split=True)
plt.title('Violin Plot: Diastolic Blood Pressure (ap_lo) vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('Diastolic Blood Pressure (ap_lo)')
plt.show()

# %%
# Compute correlation matrix
ap_lo_corr = data[['ap_lo', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(ap_lo_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: ap_lo vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## cholesterol

# %%
cholesterol = data[['cholesterol','cardio']]
cholesterol
# Out:
#        cholesterol  cardio
# 0                1       0
# 1                3       1
# 2                3       1
# 3                1       1
# 4                1       0
# ...            ...     ...
# 68200            1       0
# 68201            2       1
# 68202            3       1
# 68203            1       1
# 68204            2       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='cholesterol', hue='cardio', palette="Set2")
plt.title('Cholesterol Levels vs Cardiovascular Disease')
plt.xlabel('Cholesterol Level (1 = Normal, 2 = Above Normal, 3 = Well Above Normal)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Calculate proportions
cholesterol_cardio = data.groupby(['cholesterol', 'cardio']).size().reset_index(name='count')
cholesterol_cardio['proportion'] = cholesterol_cardio['count'] / cholesterol_cardio.groupby('cholesterol')['count'].transform('sum')

# Plot proportion barplot
plt.figure(figsize=(8, 6))
sns.barplot(data=cholesterol_cardio, x='cholesterol', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Cholesterol Level')
plt.xlabel('Cholesterol Level (1 = Normal, 2 = Above Normal, 3 = Well Above Normal)')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Compute correlation matrix
cholesterol_corr = data[['cholesterol', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(cholesterol_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Cholesterol vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## gluc

# %%
gluc = data[['gluc','cardio']]
gluc
# Out:
#        gluc  cardio
# 0         1       0
# 1         1       1
# 2         1       1
# 3         1       1
# 4         1       0
# ...     ...     ...
# 68200     1       0
# 68201     2       1
# 68202     1       1
# 68203     2       1
# 68204     1       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='gluc', hue='cardio', palette="Set2")
plt.title('Glucose Levels vs Cardiovascular Disease')
plt.xlabel('Glucose Level (1 = Normal, 2 = Above Normal, 3 = Well Above Normal)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Calculate proportions
gluc_cardio = data.groupby(['gluc', 'cardio']).size().reset_index(name='count')
gluc_cardio['proportion'] = gluc_cardio['count'] / gluc_cardio.groupby('gluc')['count'].transform('sum')

# Plot proportion barplot
plt.figure(figsize=(8, 6))
sns.barplot(data=gluc_cardio, x='gluc', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Glucose Level')
plt.xlabel('Glucose Level (1 = Normal, 2 = Above Normal, 3 = Well Above Normal)')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Compute correlation matrix
gluc_corr = data[['gluc', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(gluc_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Glucose vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## smoke

# %%
smoke = data[['smoke','cardio']]
smoke
# Out:
#        smoke  cardio
# 0          0       0
# 1          0       1
# 2          0       1
# 3          0       1
# 4          0       0
# ...      ...     ...
# 68200      1       0
# 68201      0       1
# 68202      0       1
# 68203      0       1
# 68204      0       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='smoke', hue='cardio', palette="Set2")
plt.title('Smoking Status vs Cardiovascular Disease')
plt.xlabel('Smoking Status (0 = Non-Smoker, 1 = Smoker)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Calculate proportions
smoke_cardio = data.groupby(['smoke', 'cardio']).size().reset_index(name='count')
smoke_cardio['proportion'] = smoke_cardio['count'] / smoke_cardio.groupby('smoke')['count'].transform('sum')

# Plot proportion barplot
plt.figure(figsize=(8, 6))
sns.barplot(data=smoke_cardio, x='smoke', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Smoking Status')
plt.xlabel('Smoking Status (0 = Non-Smoker, 1 = Smoker)')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Compute correlation matrix
smoke_corr = data[['smoke', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(smoke_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Smoking vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## alco

# %%
alco = data[['alco','cardio']]
alco
# Out:
#        alco  cardio
# 0         0       0
# 1         0       1
# 2         0       1
# 3         0       1
# 4         0       0
# ...     ...     ...
# 68200     0       0
# 68201     0       1
# 68202     1       1
# 68203     0       1
# 68204     0       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='alco', hue='cardio', palette="Set2")
plt.title('Alcohol Consumption vs Cardiovascular Disease')
plt.xlabel('Alcohol Consumption (0 = Non-Drinker, 1 = Drinker)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Calculate proportions
alco_cardio = data.groupby(['alco', 'cardio']).size().reset_index(name='count')
alco_cardio['proportion'] = alco_cardio['count'] / alco_cardio.groupby('alco')['count'].transform('sum')

# Plot proportion barplot
plt.figure(figsize=(8, 6))
sns.barplot(data=alco_cardio, x='alco', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Alcohol Consumption')
plt.xlabel('Alcohol Consumption (0 = Non-Drinker, 1 = Drinker)')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Compute correlation matrix
alco_corr = data[['alco', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(alco_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Alcohol Consumption vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## active

# %%
active = data[['active','cardio']]

# %%
active
# Out:
#        active  cardio
# 0           1       0
# 1           1       1
# 2           0       1
# 3           1       1
# 4           0       0
# ...       ...     ...
# 68200       1       0
# 68201       1       1
# 68202       0       1
# 68203       0       1
# 68204       1       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Countplot to visualize the relationship between 'active' and 'cardio'
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='active', hue='cardio', palette="Set2")
plt.title('Physical Activity vs Cardiovascular Disease')
plt.xlabel('Physical Activity (0 = Not Active, 1 = Active)')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Calculate proportions
active_cardio = data.groupby(['active', 'cardio']).size().reset_index(name='count')
active_cardio['proportion'] = active_cardio['count'] / active_cardio.groupby('active')['count'].transform('sum')

# Plot proportion barplot
plt.figure(figsize=(8, 6))
sns.barplot(data=active_cardio, x='active', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Physical Activity')
plt.xlabel('Physical Activity (0 = Not Active, 1 = Active)')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.show()

# %%
# Compute correlation matrix
active_corr = data[['active', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(active_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Physical Activity vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## bmi

# %%
bmi = data[['bmi','cardio']]
bmi
# Out:
#              bmi  cardio
# 0      21.967120       0
# 1      34.927679       1
# 2      23.507805       1
# 3      28.710479       1
# 4      23.011177       0
# ...          ...     ...
# 68200  26.927438       0
# 68201  50.472681       1
# 68202  31.353579       1
# 68203  27.099251       1
# 68204  24.913495       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='bmi', y='cardio', alpha=0.6)
plt.title('Scatter Plot: BMI vs Cardiovascular Disease')
plt.xlabel('BMI')
plt.ylabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='cardio', y='bmi', palette="Set2")
plt.title('Boxplot: BMI vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('BMI')
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Disease'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=data, x='cardio', y='bmi', palette="Set3", split=True)
plt.title('Violin Plot: BMI vs Cardiovascular Disease')
plt.xlabel('Cardiovascular Disease (0 = No, 1 = Yes)')
plt.ylabel('BMI')
plt.show()

# %%
# Compute correlation matrix
bmi_corr = data[['bmi', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(bmi_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: BMI vs Cardiovascular Disease')
plt.show()

# %% [markdown]
# ## bp_category

# %%
bp_category = data[['bp_category','cardio']]
bp_category
# Out:
#                 bp_category  cardio
# 0      Hypertension Stage 1       0
# 1      Hypertension Stage 2       1
# 2      Hypertension Stage 1       1
# 3      Hypertension Stage 2       1
# 4                    Normal       0
# ...                     ...     ...
# 68200  Hypertension Stage 1       0
# 68201  Hypertension Stage 2       1
# 68202  Hypertension Stage 2       1
# 68203  Hypertension Stage 1       1
# 68204  Hypertension Stage 1       0
#
# [68205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Countplot to visualize the relationship between 'bp_category' and 'cardio'
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='bp_category', hue='cardio', palette="Set2")
plt.title('Blood Pressure Category vs Cardiovascular Disease')
plt.xlabel('Blood Pressure Category')
plt.ylabel('Count')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate proportions
bp_category_cardio = data.groupby(['bp_category', 'cardio']).size().reset_index(name='count')
bp_category_cardio['proportion'] = bp_category_cardio['count'] / bp_category_cardio.groupby('bp_category')['count'].transform('sum')

# Plot proportion barplot
plt.figure(figsize=(10, 6))
sns.barplot(data=bp_category_cardio, x='bp_category', y='proportion', hue='cardio', palette="Set2")
plt.title('Proportion of Cardiovascular Disease by Blood Pressure Category')
plt.xlabel('Blood Pressure Category')
plt.ylabel('Proportion')
plt.legend(title='Cardio', labels=['No Disease', 'Disease'])
plt.xticks(rotation=45)
plt.show()

# %%
# Encode 'bp_category' for correlation analysis
data['bp_category_encoded'] = data['bp_category'].astype('category').cat.codes

# Compute correlation matrix
bp_category_corr = data[['bp_category_encoded', 'cardio']].corr()

# Plot correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(bp_category_corr, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title('Correlation Heatmap: Blood Pressure Category vs Cardiovascular Disease')
plt.show()
# Out:
# <ipython-input-157-8e5bf002cb82>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['bp_category_encoded'] = data['bp_category'].astype('category').cat.codes

# %% [markdown]
# # Take the Essential columns

# %%
data = data[['id', 'gender', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio', 'age_years', 'bmi', 'bp_category_encoded']]
data
# Out:
#           id  gender  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0          0       2    110     80            1     1      0     0       1
# 1          1       1    140     90            3     1      0     0       1
# 2          2       1    130     70            3     1      0     0       0
# 3          3       2    150    100            1     1      0     0       1
# 4          4       1    100     60            1     1      0     0       0
# ...      ...     ...    ...    ...          ...   ...    ...   ...     ...
# 68200  99993       2    120     80            1     1      1     0       1
# 68201  99995       1    140     90            2     2      0     0       1
# 68202  99996       2    180     90            3     1      0     1       0
# 68203  99998       1    135     80            1     2      0     0       0
# 68204  99999       1    120     80            2     1      0     0       1
#
#        cardio  age_years        bmi  bp_category_encoded
# ...

# %%
import numpy as np

# Function to detect outliers using IQR
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# List of numerical columns to check for outliers
numerical_columns = ['ap_hi', 'ap_lo', 'bmi', 'age_years']

# Detect and print outliers for each numerical column
for column in numerical_columns:
    # print(f"Outliers in {column}:")
    outliers = detect_outliers_iqr(data, column)
    # print(outliers)
    # print(f"Number of outliers: {len(outliers)}\n")

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Plot boxplots for numerical columns
# plt.figure(figsize=(15, 10))
# for i, column in enumerate(numerical_columns, 1):
#     plt.subplot(2, 2, i)
#     sns.boxplot(data=data, y=column, palette="Set3")
#     plt.title(f"Boxplot of {column}")

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Find Important Features Using RFE

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

# Define the features (X) and target (y)
X = data.drop(columns=['id', 'cardio'])  # Exclude 'id' and target 'cardio'
y = data['cardio']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize a Random Forest Classifier
model = RandomForestClassifier(random_state=42)

# Apply RFE to identify important features
rfe = RFE(estimator=model, n_features_to_select=5)  # Select top 5 features
rfe.fit(X_train, y_train)

# Get the ranking of features
ranking = pd.DataFrame({
    'Feature': X.columns,
    'Ranking': rfe.ranking_,
    'Support': rfe.support_  # Boolean indicating if the feature was selected
}).sort_values(by='Ranking')

# Display the top features
print("Top Features Based on RFE:")
print(ranking[ranking['Support'] == True])
# Out:
# Top Features Based on RFE:
#        Feature  Ranking  Support
# 1        ap_hi        1     True
# 2        ap_lo        1     True
# 3  cholesterol        1     True
# 8    age_years        1     True
# 9          bmi        1     True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the rankings for better visualization
ranking_sorted = ranking.sort_values(by='Ranking')

# Generate a color palette
colors = sns.color_palette('husl', len(ranking_sorted))

# Plot the feature importance rankings with colorful bars
plt.figure(figsize=(12, 8))
plt.bar(ranking_sorted['Feature'], ranking_sorted['Ranking'], color=colors, edgecolor='black')
plt.title('Feature Importance Rankings Based on RFE', fontsize=16)
plt.xlabel('Features', fontsize=14)
plt.ylabel('Importance Level (Lower is Better)', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# # Apply TSNE

# %%
from sklearn.manifold import TSNE

# Apply t-SNE
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
X_tsne = tsne.fit_transform(X_scaled)

# Plot t-SNE results
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=data['cardio'], cmap='viridis', alpha=0.7)
plt.colorbar(label='Cardio')
plt.title('t-SNE Visualization')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
# Factor Analysis

# %% [markdown]
# # Factor Analysis

# %%
from sklearn.decomposition import FactorAnalysis

# Apply Factor Analysis
factor_analysis = FactorAnalysis(n_components=2, random_state=42)
X_fa = factor_analysis.fit_transform(X_scaled)

# Plot Factor Analysis results
plt.figure(figsize=(8, 6))
plt.scatter(X_fa[:, 0], X_fa[:, 1], c=data['cardio'], cmap='viridis', alpha=0.7)
plt.colorbar(label='Cardio')
plt.title('Factor Analysis Visualization')
plt.xlabel('Factor 1')
plt.ylabel('Factor 2')
plt.show()

# Feature contributions to the factors
fa_df = pd.DataFrame(factor_analysis.components_, columns=X.columns, index=[f'Factor{i}' for i in range(1, 3)])
print("Feature contributions to Factors:")
print(fa_df.T)
# Out:
# Feature contributions to Factors:
#               Factor1   Factor2
# gender       0.071696  0.428320
# ap_hi        0.910058 -0.016136
# ap_lo        0.801309 -0.006854
# cholesterol  0.225815 -0.020491
# gluc         0.119631 -0.027300
# smoke        0.042536  0.781822
# alco         0.047255  0.423761
# active      -0.001572  0.033309
# age_years    0.226529 -0.081164
# bmi          0.257832 -0.070474

# %% [markdown]
# # Apply some model

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# Load dataset
X = data.drop(columns=['id', 'cardio'])
y = data['cardio']

# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
# Define models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "XGBoost": XGBClassifier(eval_metric='logloss'),
    "LightGBM": LGBMClassifier()
}

# %%
# Dictionary to store model performance
model_performance = {}

for model_name, model in models.items():
    print(f"Training {model_name}...")
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions on the test set
    y_pred = model.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    model_performance[model_name] = accuracy
    
    print(f"{model_name} Test Accuracy: {accuracy}\n")
# Out:
# Training Logistic Regression...
# Logistic Regression Test Accuracy: 0.7228032450395856
#
# Training Random Forest...
# Random Forest Test Accuracy: 0.6840973511875672
#
# Training Support Vector Machine...
# Support Vector Machine Test Accuracy: 0.7260776072720164
#
# Training K-Nearest Neighbors...
# K-Nearest Neighbors Test Accuracy: 0.6917701104486365
#
# Training Decision Tree...
# Decision Tree Test Accuracy: 0.638989346104975
#
# Training Naive Bayes...
# Naive Bayes Test Accuracy: 0.7108298309060698
#
# Training Gradient Boosting...
# Gradient Boosting Test Accuracy: 0.7271527709901281
#
# Training AdaBoost...
# AdaBoost Test Accuracy: 0.7228521161176815
#
# Training XGBoost...
# XGBoost Test Accuracy: 0.7265663180529762
#
# Training LightGBM...
# [LightGBM] [Info] Number of positive: 23605, number of negative: 24138
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005505 seconds.
# ...

# %%
# Find the best-performing model
best_model_name = max(model_performance, key=model_performance.get)
best_model_accuracy = model_performance[best_model_name]

print(f"The best model is: {best_model_name} with an accuracy of {best_model_accuracy}")

# Save the best model name and accuracy
with open("best_model.txt", "w") as f:
    f.write(f"Best Model: {best_model_name}\n")
    f.write(f"Accuracy: {best_model_accuracy}\n")
# Out:
# The best model is: LightGBM with an accuracy of 0.7322842341902063

# %%
# Convert results to a DataFrame for better visualization
results_df = pd.DataFrame(list(model_performance.items()), columns=["Model", "Accuracy"])
results_df = results_df.sort_values(by="Accuracy", ascending=False)

print("Model Performance Summary:")
print(results_df)

# Visualize the results
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(results_df["Model"], results_df["Accuracy"], color="skyblue", edgecolor="black")
plt.title("Test Accuracy of Machine Learning Models")
plt.ylabel("Accuracy")
plt.xlabel("Models")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Model Performance Summary:
#                     Model  Accuracy
# 9                LightGBM  0.732284
# 6       Gradient Boosting  0.727153
# 8                 XGBoost  0.726566
# 2  Support Vector Machine  0.726078
# 7                AdaBoost  0.722852
# 0     Logistic Regression  0.722803
# 5             Naive Bayes  0.710830
# 3     K-Nearest Neighbors  0.691770
# 1           Random Forest  0.684097
# 4           Decision Tree  0.638989

# %% [markdown]
# # Apply top 6 model

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
# Fine-tuning Logistic Regression
lr_params = {"C": [0.1, 1, 10], "solver": ['lbfgs', 'liblinear']}
grid_lr = GridSearchCV(LogisticRegression(), param_grid=lr_params, cv=5, scoring="accuracy")
grid_lr.fit(X_train, y_train)

# Predictions
lr_best = grid_lr.best_estimator_
y_pred_lr = lr_best.predict(X_test)

# Classification Report and Confusion Matrix
print("Logistic Regression Classification Report")
print(classification_report(y_test, y_pred_lr))
cm_lr = confusion_matrix(y_test, y_pred_lr)
ConfusionMatrixDisplay(confusion_matrix=cm_lr).plot(cmap="Blues")
# Out:
# Logistic Regression Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75     10395
#            1       0.76      0.64      0.69     10067
#
#     accuracy                           0.72     20462
#    macro avg       0.73      0.72      0.72     20462
# weighted avg       0.73      0.72      0.72     20462

# %%
# Fine-tuning Gradient Boosting
gb_params = {"n_estimators": [50, 100], "learning_rate": [0.01, 0.1], "max_depth": [3, 5]}
grid_gb = GridSearchCV(GradientBoostingClassifier(), param_grid=gb_params, cv=5, scoring="accuracy")
grid_gb.fit(X_train, y_train)

# Predictions
gb_best = grid_gb.best_estimator_
y_pred_gb = gb_best.predict(X_test)

# Classification Report and Confusion Matrix
print("Gradient Boosting Classification Report")
print(classification_report(y_test, y_pred_gb))
cm_gb = confusion_matrix(y_test, y_pred_gb)
ConfusionMatrixDisplay(confusion_matrix=cm_gb).plot(cmap="Blues")
# Out:
# Gradient Boosting Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.75     10395
#            1       0.75      0.67      0.71     10067
#
#     accuracy                           0.73     20462
#    macro avg       0.73      0.73      0.73     20462
# weighted avg       0.73      0.73      0.73     20462

# %%
# Fine-tuning XGBoost
xgb_params = {"n_estimators": [50, 100], "learning_rate": [0.01, 0.1], "max_depth": [3, 5]}
grid_xgb = GridSearchCV(XGBClassifier(eval_metric='logloss'), param_grid=xgb_params, cv=5, scoring="accuracy")
grid_xgb.fit(X_train, y_train)

# Predictions
xgb_best = grid_xgb.best_estimator_
y_pred_xgb = xgb_best.predict(X_test)

# Classification Report and Confusion Matrix
print("XGBoost Classification Report")
print(classification_report(y_test, y_pred_xgb))
cm_xgb = confusion_matrix(y_test, y_pred_xgb)
ConfusionMatrixDisplay(confusion_matrix=cm_xgb).plot(cmap="Blues")
# Out:
# XGBoost Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75     10395
#            1       0.75      0.67      0.71     10067
#
#     accuracy                           0.73     20462
#    macro avg       0.73      0.73      0.73     20462
# weighted avg       0.73      0.73      0.73     20462
